# %% [markdown]
# # Analysis of ABCtoolbox results
#
# ABCtoolbox output includes:
# - retained simulations
# - marginal posterior densities
# - marginal posterior densities charecterisitcs
# - joint posterior densities
#
# In this Notebook, I:
# - reformat the marginal posterior densities charecterisitcs file so it is easily readable
# - plot a heatmap of the joint posterior densities
# - calculate the probability NEA > NWA
# - plot the marginal priors, truncated priors, and posterior denstities

# %% [markdown]
# ## Setup code

# %%
import sys, os
sys.path.append('/mnt/src/ABC_results_AJ/')
print(sys.executable)
print(sys.version)
print(sys.version_info)
print(sys.path)
# Out:
# /opt/anaconda3/bin/python
# 3.6.4 |Anaconda, Inc.| (default, Jan 16 2018, 18:10:19)
# [GCC 7.2.0]
# sys.version_info(major=3, minor=6, micro=4, releaselevel='final', serial=0)
# ['', '/opt/anaconda3/lib/python36.zip', '/opt/anaconda3/lib/python3.6', '/opt/anaconda3/lib/python3.6/lib-dynload', '/opt/anaconda3/lib/python3.6/site-packages', '/opt/anaconda3/lib/python3.6/site-packages/IPython/extensions', '/home/aglad/.ipython', '/mnt/src/ABC_results_AJ/']

# %%
# %%bash
# # sudo /opt/anaconda3/bin/conda install rpy2
# # sudo /opt/anaconda3/bin/conda install -c conda-forge ggplot

# %%
from sys import argv
import pandas as pd
# from ggplot import *
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True, style="ticks")
import numpy as np
# import rpy2
# %load_ext rpy2.ipython

from functions.assessment_functions import *

# %% [markdown]
# ## Functions

# %% [markdown]
# ## Create PCA and density plots of summary statistics

# %%
# %%bash
# if [ -e "/mnt/ABC_AJmodels_instant_newreal/input_ABCtoolbox_M2_HPC_OSG_2_pca.pdf" ]; then
#     echo "File exists"
# else
#     head -1 /mnt/ABC_AJmodels_instant_newreal/input_ABCtoolbox_M2_HPC_OSG_2.txt >/mnt/ABC_AJmodels_instant_newreal/header_M2.txt
#     Rscript /mnt/src/macsswig_simsaj/dist_plot_stats.R /mnt/ABC_AJmodels_instant_newreal/input_ABCtoolbox_M2_HPC_OSG_2.txt /mnt/ABC_AJmodels_instant_newreal/real_output_M23_IBD.summary /mnt/ABC_AJmodels_instant_newreal/header_M2.txt
# fi

# %%
# %%bash
# ls /mnt/ABC_AJmodels_instant_newreal/*pdf
# Out:
# /mnt/ABC_AJmodels_instant_newreal/input_ABCtoolbox_M2_HPC_OSG_2_params.pdf
# /mnt/ABC_AJmodels_instant_newreal/input_ABCtoolbox_M2_HPC_OSG_2_pca.pdf
# /mnt/ABC_AJmodels_instant_newreal/input_ABCtoolbox_M2_HPC_OSG_2_stats.pdf

# %% [markdown]
# ## Model Choice

# %% [markdown]
# ### Method 1
# See `/mnt/ABC_AJmodels_instant_newreal/ABC_modelchoice_chr1.ipynb`
# - filter correlated stats
# - run ABCtoolbox method to find best stats for model choice
# - use sets of stats with power greater than 0.5

# %%
path = '/mnt/ABC_AJmodels_instant_newreal'
os.chdir(path)
abc_config_name = "test_ABC_modelchoice5.txt"

[simName, obsName, outputPrefix, params_str] = read_abc_config(abc_config_name)
print(simName)

[confusionMatrix_name,
 modelChoiceValidation_name,
 modelFit_name] = get_modelchocie_files(outputPrefix)

print(confusionMatrix_name)
print(modelChoiceValidation_name)
print(modelFit_name)
# Out:
# test_ABC_modelchoice5.txt
# keepPowerStats_input_ABCtoolbox_M1_HPC_OSG_2.txt;keepPowerStats_input_ABCtoolbox_M2_HPC_OSG_2.txt;keepPowerStats_input_ABCtoolbox_M3_HPC_OSG_2.txt
# ABC_modelchoice5_1275807confusionMatrix.txt
# ABC_modelchoice5_1275807modelChoiceValidation.txt
# ABC_modelchoice5_1275807modelFit.txt

# %%
modelFit = pd.read_csv(modelFit_name, sep = '\t')
modelFit
# Out:
#    dataSet  model1_marginalDensity  model2_marginalDensity  \
# 0        0            3.639560e-30            3.705390e-27
#
#    model3_marginalDensity  model1_TukeyDepth  model2_TukeyDepth  \
# 0            2.992580e-27           0.003003           0.002002
#
#    model3_TukeyDepth  model1_BayesFactor  model2_BayesFactor  \
# 0           0.001001            0.000543             1.23669
#
#    model3_BayesFactor  model1_posteriorProbability  \
# 0            0.806836                     0.000543
#
#    model2_posteriorProbability  model3_posteriorProbability  chosenModel
# 0                     0.552911                     0.446546            2

# %%
confusionMatrix = pd.read_csv(confusionMatrix_name, sep = '\t')
confusionMatrix
# Out:
#    trueModel  model1_raw  model2_raw  model3_raw  model1_prop  model2_prop  \
# 0          0          69          60         204     0.207207     0.180180
# 1          1          12         107         214     0.036036     0.321321
# 2          2           6          75         252     0.018018     0.225225
#
#    model3_prop  falsePositives  falseNegatives
# 0     0.612613        0.027027        0.792793
# 1     0.642643        0.202703        0.678679
# 2     0.756757        0.627628        0.243243

# %%
modelChoiceValidation = pd.read_csv(modelChoiceValidation_name, sep = '\t')
modelChoiceValidation.head()
# Out:
#    trueModel   obsNum  model1_marginalDensity  model2_marginalDensity  \
# 0          0  1273944            1.343180e-31            2.861390e-31
# 1          1  1273746            8.134000e-34            5.782590e-32
# 2          2  1274989            7.550730e-30            1.357150e-29
# 3          0  1269131            1.748000e-27            4.753440e-27
# 4          1  1268917            3.088680e-38            3.626570e-30
#
#    model3_marginalDensity  model1_BayesFactor  model2_BayesFactor  \
# 0            3.786440e-31        2.020480e-01            0.557817
# 1            7.552860e-32        6.099530e-03            0.757459
# 2            3.175340e-29        1.665910e-01            0.345296
# 3            1.110710e-26        1.102110e-01            0.369769
# 4            8.325860e-30        2.584150e-09            0.435579
#
#    model3_BayesFactor  model1_posteriorProbability  \
# 0            0.900553                 1.680870e-01
# 1            1.288020                 6.062550e-03
# 2            1.503310                 1.428020e-01
# 3            1.708410                 9.927000e-02
# 4            2.295790                 2.584150e-09
#
#    model2_posteriorProbability  model3_posteriorProbability  chosenModel
# 0                     0.358076                     0.473837            2
# 1                     0.430997                     0.562941            2
# 2                     0.256669                     0.600529            2
# 3                     0.269950                     0.630780            2
# 4                     0.303417                     0.696583            2

# %% [markdown]
# Model 3 is the true model, but Model 2 is chosen as the best model with a larger Bayes Factor than Model 3.

# %%
chosenM2_M3true = modelChoiceValidation.loc[(modelChoiceValidation['trueModel'] == 2) & (modelChoiceValidation['model2_BayesFactor'] > modelChoiceValidation['model3_BayesFactor']) & (modelChoiceValidation['chosenModel'] == 1)]
chosenM2_M3true.head()
# Out:
#     trueModel   obsNum  model1_marginalDensity  model2_marginalDensity  \
# 8           2  1267886            3.002250e-31            5.764080e-31
# 14          2  1264254            2.248180e-37            4.807230e-32
# 17          2  1249249            8.184250e-39            1.756580e-31
# 20          2  1248606            4.327740e-31            1.885890e-30
# 29          2  1230614            9.061950e-33            6.662330e-32
#
#     model3_marginalDensity  model1_BayesFactor  model2_BayesFactor  \
# 8             5.306880e-31        2.711820e-01            0.693705
# 14            3.301810e-32        2.772440e-06            1.455930
# 17            1.698280e-31        2.368910e-08            1.034330
# 20            1.389750e-30        1.321190e-01            1.034760
# 29            5.782110e-32        7.281930e-02            0.996116
#
#     model3_BayesFactor  model1_posteriorProbability  \
# 8             0.605371                 2.133310e-01
# 14            0.686838                 2.772430e-06
# 17            0.966810                 2.368910e-08
# 20            0.599378                 1.167000e-01
# 29            0.763968                 6.787660e-02
#
#     model2_posteriorProbability  model3_posteriorProbability  chosenModel
# 8                      0.409578                     0.377091            1
# 14                     0.592822                     0.407175            1
# 17                     0.508437                     0.491563            1
# 20                     0.508543                     0.374757            1
# 29                     0.499027                     0.433096            1

# %% [markdown]
# Model 1 is the true model, but Model 2 is chosen as the best model with a larger Bayes Factor than Model 1.

# %%
chosenM2_M1true = modelChoiceValidation.loc[(modelChoiceValidation['trueModel'] == 0) & (modelChoiceValidation['model2_BayesFactor'] > modelChoiceValidation['model1_BayesFactor']) & (modelChoiceValidation['chosenModel'] == 1)]
chosenM2_M1true.head()
# Out:
#     trueModel   obsNum  model1_marginalDensity  model2_marginalDensity  \
# 6           0  1263328            6.471750e-27            6.266150e-25
# 15          0  1252127            2.529520e-29            1.323880e-28
# 21          0  1249175            2.664720e-27            1.012560e-26
# 33          0  1240283            9.009560e-27            2.518760e-25
# 48          0  1197378            1.787230e-22            2.221610e-20
#
#     model3_marginalDensity  model1_BayesFactor  model2_BayesFactor  \
# 6             6.669430e-26            0.009335             8.56429
# 15            9.067680e-29            0.113399             1.14155
# 21            9.306190e-27            0.137132             0.84585
# 33            1.126850e-25            0.024713             2.06973
# 48            1.506240e-20            0.004794             1.45765
#
#     model3_BayesFactor  model1_posteriorProbability  \
# 6             0.105348                     0.009248
# 15            0.575057                     0.101849
# 21            0.727597                     0.120594
# 33            0.431934                     0.024117
# 48            0.672582                     0.004771
#
#     model2_posteriorProbability  model3_posteriorProbability  chosenModel
# 6                      0.895444                     0.095307            1
# 15                     0.533049                     0.365102            1
# 21                     0.458244                     0.421161            1
# 33                     0.674239                     0.301644            1
# 48                     0.593107                     0.402122            1

# %%
sns.kdeplot(chosenM2_M1true['model2_BayesFactor'], label = 'M2 Bayes Factor when M1 true');
sns.kdeplot(chosenM2_M3true['model2_BayesFactor'], label = 'M2 Bayes Factor when M3 true');
plt.xlabel('M2 Bayes Factor');
plt.axvline(float(modelFit['model2_BayesFactor']), color='black', label = 'model 2');

# %% [markdown]
# Proportion of Model 2 Bayes factor from real data greater than cross validation Model 2 Bayes factors incorrectly chosen when Model 1 is true

# %%
len(chosenM2_M1true.loc[chosenM2_M1true['model2_BayesFactor'] < float(modelFit['model2_BayesFactor'])])/chosenM2_M1true.shape[0]
# Out:
# 0.65

# %% [markdown]
# Proportion of Model 2 Bayes factor from real data greater than cross validation Model 2 Bayes factors incorrectly chosen when Model 3 is true

# %%
len(chosenM2_M3true.loc[chosenM2_M3true['model2_BayesFactor'] < float(modelFit['model2_BayesFactor'])])/chosenM2_M3true.shape[0]
# Out:
# 0.49333333333333335

# %% [markdown]
# ### Method 2 (sanity check)
# See `/mnt/ABC_AJmodels_instant_newreal/ABC_modelchoice_chr1.ipynb`
# - use best stats from original data

# %%
path = '/mnt/ABC_AJmodels_instant_newreal/ModelChoice_orig_stats'
os.chdir(path)
abc_config_name = "test_ABC_modelchoice.txt"

[simName, obsName, outputPrefix, params_str] = read_abc_config(abc_config_name)
print(simName)

[confusionMatrix_name,
 modelChoiceValidation_name,
 modelFit_name] = get_modelchocie_files(outputPrefix)

print(confusionMatrix_name)
print(modelChoiceValidation_name)
print(modelFit_name)
# Out:
# test_ABC_modelchoice.txt
# keepPowerStats_input_ABCtoolbox_M1_HPC_OSG_2.txt;keepPowerStats_input_ABCtoolbox_M2_HPC_OSG_2.txt;keepPowerStats_input_ABCtoolbox_M3_HPC_OSG_2.txt
# ABC_modelchoice5_1275807confusionMatrix.txt
# ABC_modelchoice5_1275807modelChoiceValidation.txt
# ABC_modelchoice5_1275807modelFit.txt

# %%
modelFit = pd.read_csv(modelFit_name, sep = '\t')
modelFit
# Out:
#    dataSet  model1_marginalDensity  model2_marginalDensity  \
# 0        0            6.338700e-44            2.446080e-31
#
#    model3_marginalDensity  model1_TukeyDepth  model2_TukeyDepth  \
# 0            1.717530e-31           0.001001                  0
#
#    model3_TukeyDepth  model1_BayesFactor  model2_BayesFactor  \
# 0                  0        1.522400e-13             1.42419
#
#    model3_BayesFactor  model1_posteriorProbability  \
# 0            0.702154                 1.522400e-13
#
#    model2_posteriorProbability  model3_posteriorProbability  chosenModel
# 0                     0.587491                     0.412509            2

# %%
confusionMatrix = pd.read_csv(confusionMatrix_name, sep = '\t')
confusionMatrix
# Out:
#    trueModel  model1_raw  model2_raw  model3_raw  model1_prop  model2_prop  \
# 0          0          11           7          15     0.333333     0.212121
# 1          1           0          17          16     0.000000     0.515152
# 2          2           0           8          25     0.000000     0.242424
#
#    model3_prop  falsePositives  falseNegatives
# 0     0.454545        0.000000        0.666667
# 1     0.484848        0.227273        0.484848
# 2     0.757576        0.469697        0.242424

# %%
modelChoiceValidation = pd.read_csv(modelChoiceValidation_name, sep = '\t')
modelChoiceValidation.head()
# Out:
#    trueModel   obsNum  model1_marginalDensity  model2_marginalDensity  \
# 0          0  1268496            1.045310e-42            7.150420e-35
# 1          1  1262882            1.106540e-40            4.043180e-25
# 2          2  1250082            5.665930e-44            4.295220e-26
# 3          0  1247162            6.360170e-39            1.410410e-38
# 4          1  1201758            3.115790e-51            1.231010e-37
#
#    model3_marginalDensity  model1_BayesFactor  model2_BayesFactor  \
# 0            8.495040e-35        6.681230e-09            0.841717
# 1            7.066720e-25        9.959920e-17            0.572143
# 2            3.220820e-26        7.538460e-19            1.333580
# 3            8.342410e-39        2.833480e-01            0.959295
# 4            4.823900e-38        1.818480e-14            2.551910
#
#    model3_BayesFactor  model1_posteriorProbability  \
# 0            1.188050                 6.681230e-09
# 1            1.747810                 9.959920e-17
# 2            0.749862                 7.538460e-19
# 3            0.407657                 2.207880e-01
# 4            0.391864                 1.818480e-14
#
#    model2_posteriorProbability  model3_posteriorProbability  chosenModel
# 0                     0.457028                     0.542972            2
# 1                     0.363926                     0.636074            2
# 2                     0.571474                     0.428526            1
# 3                     0.489612                     0.289600            1
# 4                     0.718461                     0.281539            1

# %% [markdown]
# Model 3 is the true model, but Model 2 is chosen as the best model with a larger Bayes Factor than Model 3.

# %%
chosenM2_M3true = modelChoiceValidation.loc[(modelChoiceValidation['trueModel'] == 2) & (modelChoiceValidation['model2_BayesFactor'] > modelChoiceValidation['model3_BayesFactor']) & (modelChoiceValidation['chosenModel'] == 1)]
chosenM2_M3true.head()
# Out:
#     trueModel   obsNum  model1_marginalDensity  model2_marginalDensity  \
# 2           2  1250082            5.665930e-44            4.295220e-26
# 8           2  1204428            6.885590e-35            2.938900e-30
# 17          2  1163062            7.787140e-43            4.498400e-33
# 20          2  1143321            1.479990e-48            4.175090e-33
# 23          2  1099407            6.503210e-55            3.195330e-27
#
#     model3_marginalDensity  model1_BayesFactor  model2_BayesFactor  \
# 2             3.220820e-26        7.538460e-19             1.33358
# 8             1.918340e-30        1.417590e-05             1.53194
# 17            4.438110e-33        8.713850e-11             1.01358
# 20            3.429330e-33        1.946230e-16             1.21747
# 23            2.082820e-27        1.232100e-28             1.53414
#
#     model3_BayesFactor  model1_posteriorProbability  \
# 2             0.749862                 7.538460e-19
# 8             0.652726                 1.417570e-05
# 17            0.986598                 8.713850e-11
# 20            0.821378                 1.946230e-16
# 23            0.651833                 1.232100e-28
#
#     model2_posteriorProbability  model3_posteriorProbability  chosenModel
# 2                      0.571474                     0.428526            1
# 8                      0.605047                     0.394939            1
# 17                     0.503373                     0.496627            1
# 20                     0.549035                     0.450965            1
# 23                     0.605388                     0.394612            1

# %% [markdown]
# Model 1 is the true model, but Model 2 is chosen as the best model with a larger Bayes Factor than Model 1.

# %%
chosenM2_M1true = modelChoiceValidation.loc[(modelChoiceValidation['trueModel'] == 0) & (modelChoiceValidation['model2_BayesFactor'] > modelChoiceValidation['model1_BayesFactor']) & (modelChoiceValidation['chosenModel'] == 1)]
chosenM2_M1true.head()
# Out:
#     trueModel   obsNum  model1_marginalDensity  model2_marginalDensity  \
# 3           0  1247162            6.360170e-39            1.410410e-38
# 6           0  1233987            1.130940e-39            4.059140e-28
# 30          0  1017580            3.146170e-29            1.147260e-25
# 36          0   940356            8.602930e-47            7.903640e-30
# 57          0   611081            3.421380e-35            6.011570e-29
#
#     model3_marginalDensity  model1_BayesFactor  model2_BayesFactor  \
# 3             8.342410e-39        2.833480e-01            0.959295
# 6             2.975740e-28        1.607620e-12            1.364080
# 30            5.147350e-26        1.893010e-04            2.227470
# 36            3.993280e-30        7.231230e-18            1.979240
# 57            4.677250e-29        3.200890e-07            1.285280
#
#     model3_BayesFactor  model1_posteriorProbability  \
# 3             0.407657                 2.207880e-01
# 6             0.733097                 1.607620e-12
# 30            0.448543                 1.892650e-04
# 36            0.505245                 7.231230e-18
# 57            0.778040                 3.200890e-07
#
#     model2_posteriorProbability  model3_posteriorProbability  chosenModel
# 3                      0.489612                     0.289600            1
# 6                      0.577002                     0.422998            1
# 30                     0.690160                     0.309651            1
# 36                     0.664343                     0.335657            1
# 57                     0.562417                     0.437583            1

# %%
sns.kdeplot(chosenM2_M1true['model2_BayesFactor'], label = 'M2 Bayes Factor when M1 true');
sns.kdeplot(chosenM2_M3true['model2_BayesFactor'], label = 'M2 Bayes Factor when M3 true');
plt.xlabel('M2 Bayes Factor');
plt.axvline(float(modelFit['model2_BayesFactor']), color='black', label = 'model 2');

# %% [markdown]
# Proportion of Model 2 Bayes factor from real data greater than cross validation Model 2 Bayes factors incorrectly chosen when Model 1 is true

# %%
len(chosenM2_M1true.loc[chosenM2_M1true['model2_BayesFactor'] < float(modelFit['model2_BayesFactor'])])/chosenM2_M1true.shape[0]
# Out:
# 0.42857142857142855

# %% [markdown]
# Proportion of Model 2 Bayes factor from real data greater than cross validation Model 2 Bayes factors incorrectly chosen when Model 3 is true

# %%
len(chosenM2_M3true.loc[chosenM2_M3true['model2_BayesFactor'] < float(modelFit['model2_BayesFactor'])])/chosenM2_M3true.shape[0]
# Out:
# 0.625

# %% [markdown]
# ## Correlated Stats Pruned

# %% [markdown]
# ### Model 2

# %%
path = '/mnt/ABC_AJmodels_instant_newreal'
os.chdir(path)
abc_config_name = "test_ABC_correlatedstats6.txt"

[simName, obsName, outputPrefix, params_str] = read_abc_config(abc_config_name)
print(simName)

[BestSimsParamStats_name,
 MarginalPosteriorDensities_name,
 MarginalPosteriorCharacteristics_name,
 jointPosterior_name,
 MarginalPosteriorCharacteristics_reformat_name,
modelFit_name] = get_results_files(outputPrefix)
print(BestSimsParamStats_name)
print(MarginalPosteriorDensities_name)
print(jointPosterior_name)
print(MarginalPosteriorCharacteristics_reformat_name)
print(modelFit_name)
# Out:
# test_ABC_correlatedstats6.txt
# input_ABCtoolbox_M2_HPC_OSG_2.txt
# ABC_correlatedstats6_1446125_pruneCorStats_90_model0_BestSimsParamStats_Obs0.txt
# ABC_correlatedstats6_1446125_pruneCorStats_90_model0_MarginalPosteriorDensities_Obs0.txt
# ABC_correlatedstats6_1446125_pruneCorStats_90_model0_jointPosterior_8_9_Obs0.txt
# ABC_correlatedstats6_1446125_pruneCorStats_90_model0_MarginalPosteriorCharacteristicsReformat.txt
# ABC_correlatedstats6_1446125_pruneCorStats_90_modelFit.txt

# %% [markdown]
# #### Reformat marginal posterior densities charecterisitcs file

# %%
df_chrs_reformat = reformat_Characteristics(MarginalPosteriorCharacteristics_name)
df_chrs_reformat
# Out:
# parsing ABC_correlatedstats6_1446125_pruneCorStats_90_model0_MarginalPosteriorCharacteristics.txt
# /mnt/src/ABC_results_AJ/functions/assessment_functions.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df
# 4  0529171496063882_1991        9       17         2  0.064633   4.903692
#
#    Log10_NANC  Log10_NCEU  Log10_NCHB  Log10_NWA     ...       FST_AfAs_ASC_m  \
# 0    4.002598    4.391129    4.266279   5.365600     ...             0.104465
# 1    3.581722    3.123198    4.217510   6.341655     ...             0.478686
# 2    3.483730    3.096910    3.823735   3.288249     ...             0.339033
# 3    4.376741    4.335538    4.876541   6.579049     ...             0.059878
# 4    4.056524    3.635685    3.772908   5.502117     ...             0.091493
#
#    FST_EuAs_ASC  FST_eAwA_ASC  FST_eAEu_ASC  FST_eAJ_ASC  FST_eAM_ASC  \
# 0      0.057020      0.002686      0.150827     0.008299     0.026635
# 1      0.407555      0.001390      0.297388     0.000290     0.083451
# 2      0.070902      0.001375      0.084863     0.008412     0.025681
# 3      0.036267     -0.000017      0.027780     0.000749     0.036373
# 4      0.026036      0.000894      0.067956     0.004092     0.003518
#
#    FST_MJ_ASC  FST_wAEu_ASC  FST_wAJ_ASC  FST_wAM_ASC
# 0    0.024294      0.150963     0.009419     0.028186
# 1    0.085553      0.299524     0.001247     0.085223
# 2    0.021827      0.083589     0.008920     0.026500
# 3    0.034299      0.029181     0.001784     0.037691
# 4    0.003223      0.066293     0.004558     0.003142
#
# [5 rows x 205 columns]

# %%
truncated = pd.read_csv(BestSimsParamStats_name, sep = '\t')
truncated.head()
# Out:
#    Sim_num        Dist  Asc_NAF  Asc_NEU  Asc_NCHB       daf  Log10_NAF  \
# 0       23  74533600.0        5       13        17  0.076029    4.26283
# 1      102  49229600.0        5        4         5  0.087403    4.97663
# 2      339  39340100.0       17        3         5  0.057562    4.27655
# 3      405  27171100.0       10        4         7  0.062405    3.82073
# 4      526  82716000.0        9       15        14  0.072339    4.19165
#
#    Log10_NCEU  Log10_NCHB  Log10_NWA     ...       FST_AfAs_ASC_m  \
# 0     4.57862     3.61321    4.30494     ...             0.220007
# 1     4.42085     3.01912    6.20675     ...             0.267957
# 2     3.31806     3.41664    6.63939     ...             0.289477
# 3     4.24957     3.66717    3.08350     ...             0.189929
# 4     4.69258     3.83594    5.20930     ...             0.072436
#
#    FST_EuAs_ASC  FST_eAwA_ASC  FST_eAEu_ASC  FST_eAJ_ASC  FST_eAM_ASC  \
# 0      0.170124     -0.000300      0.176386     0.000825     0.001011
# 1      0.127303      0.006482      0.151521     0.018406     0.023591
# 2      0.105329     -0.000158      0.073787     0.004285     0.019499
# 3      0.124689      0.021863      0.126657     0.011762     0.013374
# 4      0.093768     -0.000451      0.101605     0.002258     0.021541
#
#    FST_MJ_ASC  FST_wAEu_ASC  FST_wAJ_ASC  FST_wAM_ASC
# 0    0.001988      0.176816     0.000408     0.001515
# 1    0.002097      0.146635     0.016520     0.021877
# 2    0.025207      0.071067     0.003714     0.020997
# 3    0.001696      0.134205     0.013356     0.016041
# 4    0.020686      0.100555     0.000688     0.020075
#
# [5 rows x 203 columns]

# %%
posterior = pd.read_csv(MarginalPosteriorDensities_name, sep = '\t')
posterior.head()
# Out:
#    number  Asc_NAF  Asc_NAF.density  Asc_NEU  Asc_NEU.density  Asc_NCHB  \
# 0       1  2.00000         0.024967  2.00000         0.036374   2.00000
# 1       2  2.18182         0.026827  2.18182         0.038767   2.18182
# 2       3  2.36364         0.028650  2.36364         0.041083   2.36364
# 3       4  2.54545         0.030419  2.54545         0.043301   2.54545
# 4       5  2.72727         0.032121  2.72727         0.045402   2.72727
#
#    Asc_NCHB.density       daf  daf.density  Log10_NAF     ...       Teu_as  \
# 0          0.040444  0.050000      1.21222    3.70001     ...      402.000
# 1          0.043292  0.050505      1.37876    3.71314     ...      439.313
# 2          0.046060  0.051010      1.55826    3.72627     ...      476.626
# 3          0.048721  0.051515      1.75040    3.73940     ...      513.939
# 4          0.051253  0.052020      1.95468    3.75254     ...      551.253
#
#    Teu_as.density       TA  TA.density     TMJ  TMJ.density     TAEW  \
# 0        0.000601  20.0000    0.043261  21.000     0.000891  2.00000
# 1        0.000641  20.1616    0.045882  32.899     0.000964  2.32323
# 2        0.000680  20.3232    0.048396  44.798     0.001037  2.64646
# 3        0.000717  20.4848    0.050782  56.697     0.001109  2.96970
# 4        0.000751  20.6465    0.053027  68.596     0.001180  3.29293
#
#    TAEW.density       Tm  Tm.density
# 0      0.019405  3.00000    0.003251
# 1      0.020870  3.32323    0.003642
# 2      0.022308  3.64646    0.004061
# 3      0.023705  3.96970    0.004510
# 4      0.025049  4.29293    0.004988
#
# [5 rows x 41 columns]

# %%
param_indexes = get_param_indexes(params_str)
params = get_col_names(param_indexes, prior)

# %%
df_chrs_reformat.head()
# Out:
#         mode       mean     median  q50_lower  q50_upper  q90_lower  \
# 0  12.909100  11.625500  11.880800   7.751050  15.633200   3.548860
# 0   9.818180  10.611900  10.433200   6.631590  14.544700   3.151130
# 0   6.000000  10.170600   9.881890   6.073830  14.107000   3.038460
# 0   0.092424   0.083989   0.085993   0.077007   0.092687   0.062214
# 0   4.395960   4.359610   4.367000   4.102230   4.617940   3.826580
#
#    q90_upper  q95_lower  q95_upper  q99_lower  q99_upper  HDI50_lower  \
# 0  18.910900    2.85590  19.416400   2.192680  19.873900     9.909090
# 0  18.545100    2.62025  19.197400   2.134590  19.820600     4.997470
# 0  18.241400    2.55876  18.999100   2.121480  19.765100     3.363640
# 0   0.098205    0.05828   0.099057   0.052879   0.099799     0.084091
# 0   4.876860    3.77396   4.928850   3.718010   4.983110     4.165990
#
#    HDI50_upper  HDI90_lower  HDI90_upper  HDI95_lower  HDI95_upper  \
# 0    17.580500     4.454550     19.69410     3.545450     19.99660
# 0    12.818200     2.636360     17.98140     2.272730     18.80330
# 0    11.033300     2.188400     17.18180     2.000000     18.24140
# 0     0.097815     0.067593      0.10000     0.062214      0.10000
# 0     4.678280     3.825020      4.87525     3.772920      4.92777
#
#    HDI99_lower  HDI99_upper      param
# 0     2.372300     20.00000    Asc_NAF
# 0     2.000000     19.65250    Asc_NEU
# 0     2.000000     19.55160   Asc_NCHB
# 0     0.054691      0.10000        daf
# 0     3.719710      4.98471  Log10_NAF

# %%
for param in params:
    plot_param_densities(posterior, truncated, prior, df_chrs_reformat, param)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-1ec2c22928ed> in <module>()
#       1 for param in params:
# ----> 2     plot_param_densities(posterior, truncated, prior, df_chrs_reformat, param)
#
# /mnt/src/ABC_results_AJ/functions/assessment_functions.py in plot_param_densities(posterior, truncated, prior, df_chrs_reformat, param)
#     180     """
#     181
# --> 182     mode = float(df_chrs_reformat['mode'].loc[df_chrs_reformat['param'] == param])
#     183     HDI90_lower = float(df_chrs_reformat['HDI90_lower'].loc[df_chrs_reformat['param'] == param])
#     184     HDI90_upper = float(df_chrs_reformat['HDI90_upper'].loc[df_chrs_reformat['param'] == param])
#
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in wrapper(self)
#     110             return converter(self.iloc[0])
#     111         raise TypeError("cannot convert the series to "
# --> 112                         "{0}".format(str(converter)))
#     113
#     114     return wrapper
#
# TypeError: cannot convert the series to <class 'float'>

# %% [markdown]
# #### Joint density plot

# %% [markdown]
# Create joint density dataframe

# %%
joint_NEA_NWA_df = create_joint_df(jointPosterior_name)
joint_NEA_NWA_df.head()
# Out:
#    number  Log10_NWA  Log10_NEA  density       HDI
# 0       0    3.00000        4.0  2.64562  0.999800
# 1       1    3.03737        4.0  2.88943  0.999544
# 2       2    3.07475        4.0  3.13849  0.999187
# 3       3    3.11212        4.0  3.39144  0.998674
# 4       4    3.14949        4.0  3.64696  0.997970

# %%
prob = get_prob_NEA_grtr_NWA(joint_NEA_NWA_df)
print(prob)
# Out:
# 0.6734618390852632

# %%
plot_joint_mtpltlb(joint_NEA_NWA_df, df_chrs_reformat)
# Out:
# /mnt/src/ABC_results_AJ/functions/assessment_functions.py:221: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   Z = z.reshape(len(NEA), len(NWA))

# %% [markdown]
# ## PLS

# %% [markdown]
# ### Model 2

# %%
path = '/mnt/ABC_AJmodels_instant_newreal/PLS'
os.chdir(path)
abc_config_name = "test_ABC_estimate_M2_PLS.txt"

[simName, obsName, outputPrefix, params_str] = read_abc_config(abc_config_name)
print(simName)

[BestSimsParamStats_name,
 MarginalPosteriorDensities_name,
 MarginalPosteriorCharacteristics_name,
 jointPosterior_name,
 MarginalPosteriorCharacteristics_reformat_name,
modelFit] = get_results_files(outputPrefix)
print(BestSimsParamStats_name)
print(MarginalPosteriorDensities_name)
print(jointPosterior_name)
print(MarginalPosteriorCharacteristics_reformat_name)
# Out:
# test_ABC_estimate_M2_PLS.txt
# input_ABCtoolbox_M2_HPC_OSG_2.transformed_10pls.txt
# ABC_M2_estimate_1446125_10pls_1000ret_model0_BestSimsParamStats_Obs0.txt
# ABC_M2_estimate_1446125_10pls_1000ret_model0_MarginalPosteriorDensities_Obs0.txt
# ABC_M2_estimate_1446125_10pls_1000ret_model0_jointPosterior_8_9_Obs0.txt
# ABC_M2_estimate_1446125_10pls_1000ret_model0_MarginalPosteriorCharacteristicsReformat.txt

# %%
param_indexes = get_param_indexes(params_str)
params = get_col_names(param_indexes, prior)

# %% [markdown]
# #### Reformat marginal posterior densities charecterisitcs file

# %%
df_chrs_reformat_pls = reformat_Characteristics(MarginalPosteriorCharacteristics_name)
df_chrs_reformat_pls
# Out:
# parsing ABC_M2_estimate_1446125_10pls_1000ret_model0_MarginalPosteriorCharacteristics.txt
# /mnt/src/ABC_results_AJ/functions/assessment_functions.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df
#
#    LinearCombination_0  LinearCombination_1  LinearCombination_2  \
# 0             1.125010              0.86040             2.423170
# 1            10.571300             -7.41682             4.473280
# 2            -5.533650             -3.17681            -4.261020
# 3            -9.785690              4.81581            -0.450111
# 4             0.886967              4.40390             1.310930
#
#    LinearCombination_3  LinearCombination_4  LinearCombination_5  \
# 0            -1.240080             0.845003            -1.125590
# 1            -0.965474             4.215160            -0.527522
# 2            -1.686030             2.272880             1.961840
# 3            -0.057790             1.622090            -1.117200
# 4             1.441910             0.822246            -0.875576
#
#    LinearCombination_6  LinearCombination_7  LinearCombination_8  \
# 0             0.981563            -3.112930            -2.369540
# 1             1.450910            -3.491500            -3.786360
# 2            -1.393840            -0.596993            -0.301039
# 3            -0.433007             0.778963            -0.293196
# 4             0.238202            -4.099040            -1.115370
#
#    LinearCombination_9
# 0             1.570150
# 1             2.616750
# 2             0.893576
# 3            -0.013859
# 4             1.816170
#
# [5 rows x 34 columns]

# %%
truncated_pls = pd.read_csv(BestSimsParamStats_name, sep = '\t')
truncated_pls.head()
# Out:
#    Sim_num     Dist  Asc_NAF  Asc_NEU  Asc_NCHB       daf  Log10_NAF  \
# 0      264  16.8687        8       15         8  0.097583    3.93671
# 1     1117  15.8772       19        3        20  0.098055    4.92612
# 2     1178  15.7531       16        6        19  0.097908    4.43821
# 3     2635  13.8534        6        3         4  0.097245    4.77986
# 4     3373  16.4925        5        7         4  0.077518    4.52802
#
#    Log10_NCEU  Log10_NCHB  Log10_NWA         ...           \
# 0     4.35744     4.06247    5.20517         ...
# 1     4.05835     3.89597    4.36596         ...
# 2     4.94385     4.28883    5.64311         ...
# 3     3.89840     3.92355    5.42171         ...
# 4     3.82230     3.36342    6.30811         ...
#
#    LinearCombination_0  LinearCombination_1  LinearCombination_2  \
# 0             -14.4694             0.878387             -5.08654
# 1             -14.1798             0.576015             -4.30848
# 2             -13.6000             0.248529             -5.32594
# 3             -12.5832             0.729135             -2.31277
# 4             -13.6125            -2.511240             -1.17663
#
#    LinearCombination_3  LinearCombination_4  LinearCombination_5  \
# 0             1.787270              3.31941              3.30940
# 1             1.535540              2.54265              2.58288
# 2             0.187016              2.82822              3.45323
# 3             1.542970              3.18700              2.62611
# 4             2.896810              3.33754              4.47957
#
#    LinearCombination_6  LinearCombination_7  LinearCombination_8  \
# 0              1.75454             1.881890            -1.808710
# 1              1.78050             1.356290             0.131996
# 2              2.10797             0.942264            -1.200940
# 3              1.40639             1.475900            -0.904433
# 4              1.29533             2.474460            -0.298918
#
#    LinearCombination_9
# 0            -2.009360
# 1            -2.163160
# 2            -2.999570
# 3            -0.654759
# 4            -1.051090
#
# [5 rows x 32 columns]

# %%
posterior_pls = pd.read_csv(MarginalPosteriorDensities_name, sep = '\t')
posterior_pls.head()
# Out:
#    number  Asc_NAF  Asc_NAF.density  Asc_NEU  Asc_NEU.density  Asc_NCHB  \
# 0       1  2.00000         0.013209  2.00000         0.055210   2.00000
# 1       2  2.18182         0.014878  2.18182         0.058040   2.18182
# 2       3  2.36364         0.016658  2.36364         0.060677   2.36364
# 3       4  2.54545         0.018543  2.54545         0.063102   2.54545
# 4       5  2.72727         0.020521  2.72727         0.065299   2.72727
#
#    Asc_NCHB.density       daf  daf.density  Log10_NAF     ...       Teu_as  \
# 0          0.103986  0.050000      3.01493    3.70001     ...      402.000
# 1          0.109286  0.050505      3.14045    3.71314     ...      439.313
# 2          0.114057  0.051010      3.24845    3.72627     ...      476.626
# 3          0.118236  0.051515      3.33815    3.73940     ...      513.939
# 4          0.121775  0.052020      3.40941    3.75253     ...      551.253
#
#    Teu_as.density       TA  TA.density     TMJ  TMJ.density     TAEW  \
# 0        0.000592  20.0000    0.034464  21.000     0.001136  2.00000
# 1        0.000638  20.1616    0.036640  32.899     0.001226  2.32323
# 2        0.000682  20.3232    0.038716  44.798     0.001315  2.64646
# 3        0.000724  20.4848    0.040669  56.697     0.001400  2.96970
# 4        0.000763  20.6465    0.042482  68.596     0.001481  3.29293
#
#    TAEW.density       Tm  Tm.density
# 0      0.017954  3.00000    0.001714
# 1      0.019395  3.32323    0.001995
# 2      0.020832  3.64646    0.002310
# 3      0.022254  3.96970    0.002661
# 4      0.023649  4.29293    0.003049
#
# [5 rows x 41 columns]

# %%
for param in params:
    plot_param_densities(posterior_pls, truncated_pls, prior_pls, df_chrs_reformat_pls, param)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-e27a27114209> in <module>()
#       1 for param in params:
# ----> 2     plot_param_densities(posterior_pls, truncated_pls, prior_pls, df_chrs_reformat_pls, param)
#
# /mnt/src/ABC_results_AJ/functions/assessment_functions.py in plot_param_densities(posterior, truncated, prior, df_chrs_reformat, param)
#     180     """
#     181
# --> 182     mode = float(df_chrs_reformat['mode'].loc[df_chrs_reformat['param'] == param])
#     183     HDI90_lower = float(df_chrs_reformat['HDI90_lower'].loc[df_chrs_reformat['param'] == param])
#     184     HDI90_upper = float(df_chrs_reformat['HDI90_upper'].loc[df_chrs_reformat['param'] == param])
#
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in wrapper(self)
#     110             return converter(self.iloc[0])
#     111         raise TypeError("cannot convert the series to "
# --> 112                         "{0}".format(str(converter)))
#     113
#     114     return wrapper
#
# TypeError: cannot convert the series to <class 'float'>

# %% [markdown]
# #### Joint density plot

# %% [markdown]
# Create joint density dataframe

# %%
joint_NEA_NWA_df_pls = create_joint_df(jointPosterior_name)
joint_NEA_NWA_df_pls.head()
# Out:
#    number  Log10_NWA  Log10_NEA  density       HDI
# 0       0    3.00000        4.0  2.89802  0.997282
# 1       1    3.03737        4.0  3.07695  0.996633
# 2       2    3.07475        4.0  3.24135  0.995827
# 3       3    3.11212        4.0  3.38884  0.995046
# 4       4    3.14949        4.0  3.51763  0.994341

# %%
prob = get_prob_NEA_grtr_NWA(joint_NEA_NWA_df_pls)
print(prob)
# Out:
# 0.6848261120381732

# %%
plot_joint_mtpltlb(joint_NEA_NWA_df_pls, df_chrs_reformat_pls)
# Out:
# /mnt/src/ABC_results_AJ/functions/assessment_functions.py:221: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   Z = z.reshape(len(NEA), len(NWA))
